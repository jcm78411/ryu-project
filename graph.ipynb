# %%
import seaborn as sns
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('metrics_log.csv')
df.head(5)
# Out:
#              timestamp  switch_id        port  tx_bytes  rx_bytes  tx_packets  \
# 0  2025-05-31 19:35:34          1  4294967294         0         0           0
# 1  2025-05-31 19:35:34          1           1      2050      2050          14
# 2  2025-05-31 19:35:34          1           2      2050      1739          14
# 3  2025-05-31 19:35:34          3  4294967294         0         0           0
# 4  2025-05-31 19:35:34          3           1      2140       556          15
#
#    rx_packets     latency  switch_latency  cpu_usage  mem_usage
# 0           0  104.995723        0.003650        8.7       72.3
# 1          14  104.995723        0.003650        8.7       72.3
# 2          12  104.000000        0.003650        8.7       72.3
# 3           0   71.793142        0.002965        8.7       72.3
# 4           6   71.793142        0.002965        8.7       72.3

# %%
len(df)
# Out:
# 32844

# %%
df_clean = df.copy()
df_clean = df_clean[df_clean['port'] != 4294967294]
df_clean.head(5)
# Out:
#              timestamp  switch_id  port  tx_bytes  rx_bytes  tx_packets  \
# 1  2025-05-31 19:35:34          1     1      2050      2050          14
# 2  2025-05-31 19:35:34          1     2      2050      1739          14
# 4  2025-05-31 19:35:34          3     1      2140       556          15
# 5  2025-05-31 19:35:34          3     2      1705       646          13
# 6  2025-05-31 19:35:34          3     3      1739      2050          12
#
#    rx_packets     latency  switch_latency  cpu_usage  mem_usage
# 1          14  104.995723        0.003650        8.7       72.3
# 2          12  104.000000        0.003650        8.7       72.3
# 4           6   71.793142        0.002965        8.7       72.3
# 5           7   71.793142        0.002965        8.7       72.3
# 6          14   71.000000        0.002965        8.7       72.3

# %%
len(df_clean)
# Out:
# 23888

# %%
df_clean['switch_latency'] = (df_clean['switch_latency'] * 1000).round(2)
df_clean['latency'] = df_clean['latency'].round(0).astype(int)
df_clean.head(5)
# Out:
#              timestamp  switch_id  port  tx_bytes  rx_bytes  tx_packets  \
# 1  2025-05-31 19:35:34          1     1      2050      2050          14
# 2  2025-05-31 19:35:34          1     2      2050      1739          14
# 4  2025-05-31 19:35:34          3     1      2140       556          15
# 5  2025-05-31 19:35:34          3     2      1705       646          13
# 6  2025-05-31 19:35:34          3     3      1739      2050          12
#
#    rx_packets  latency  switch_latency  cpu_usage  mem_usage
# 1          14      105            3.65        8.7       72.3
# 2          12      104            3.65        8.7       72.3
# 4           6       72            2.96        8.7       72.3
# 5           7       72            2.96        8.7       72.3
# 6          14       71            2.96        8.7       72.3

# %%
#df_clean.drop(columns=['switch_latency_ms'], inplace=True)

# %%
df_clean.columns
# Out:
# Index(['timestamp', 'switch_id', 'port', 'tx_bytes', 'rx_bytes', 'tx_packets',
#        'rx_packets', 'latency', 'switch_latency', 'cpu_usage', 'mem_usage'],
#       dtype='object')

# %%
#df_clean.to_csv('flow/traffic_metrics_load_balancer.csv', index=False)
#df_clean.to_csv('flow/traffic_metrics_normally.csv', index=False)
df_clean.to_csv('flow/traffic_metrics_round_robin.csv', index=False)

# %%
#corr = df_clean.corr()
#plt.figure(figsize=(10, 8))
#sns.heatmap(corr, annot=True, cmap='coolwarm')
#plt.show()
